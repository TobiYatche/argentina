# %% [markdown]
# # argentina.afip — Pruebas interactivas
#
# Alícuotas IVA estables + reexports de CUIT y CLAE.
#
# **Alcance acotado a propósito:** Monotributo y Ganancias no se embeben para evitar devolver datos desactualizados silenciosamente.

# %%
import argentina as arg
print(f"argentina v{arg.__version__}")
# Out:
# argentina v0.3.0

# %% [markdown]
# ## IVA

# %%
arg.afip.alicuotas_iva()
# Out:
# {'general': 0.21, 'reducida': 0.105, 'especial': 0.27}

# %% [markdown]
# ## CUIT (reexports de `argentina.personas`)

# %%
arg.afip.formatear_cuit("20123456786")
# Out:
# '20-12345678-6'

# %%
arg.afip.validar_cuit("20-12345678-6")
# Out:
# True

# %% [markdown]
# ## CLAE (reexports de `argentina.clae`)

# %%
arg.afip.clae_lookup("620100")
# Out:
# Actividad(codigo='620100', descripcion='Servicios de consultores en informática y suministros de programas de informática', sector='J', sector_nombre='Información y comunicaciones', grupo='6201')
